# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# Define the file path
file_path = "/content/drive/MyDrive/EDA/revenuefinal.csv"

# Import the dataset
df = pd.read_csv(file_path)

# Display the first few rows to verify import
df.head()
# Out:
#    SerialNumber                                     Names   Rank Marketcap  \
# 0             1                              Shree Cement  #1344  $12.13 B
# 1             2                 Shriram Transport Finance  #1513  $10.42 B
# 2             3  National Mineral Development Corporation  #1914   $7.65 B
# 3             4                                       ACC  #2394   $5.59 B
# 4             5                             Siemens India   #985  $18.02 B
#
#   Share.Price            Categories  Revenue Country
# 0     $336.31                   NaN  $2.28 B   India
# 1      $27.76  💳 Financial services  $2.29 B   India
# 2       $2.61             ⛏️ Mining  $2.30 B   India
# 3      $29.69                Cement  $2.30 B   India
# 4      $50.60                   NaN  $2.33 B   India

# %%
# Display the column names
print(df.columns)
# Out:
# Index(['SerialNumber', 'Names', 'Rank', 'Marketcap', 'Share.Price',
#        'Categories', 'Revenue', 'Country'],
#       dtype='object')

# %%
# Display the shape of the dataset
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 100
# Number of columns: 8

# %%
# Display the dataset information
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SerialNumber  100 non-null    int64
#  1   Names         100 non-null    object
#  2   Rank          100 non-null    object
#  3   Marketcap     100 non-null    object
#  4   Share.Price   100 non-null    object
#  5   Categories    92 non-null     object
#  6   Revenue       100 non-null    object
#  7   Country       100 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 6.4+ KB
# None

# %%
# Display unique categories
unique_categories = df['Categories'].unique()
print("Unique categories:", unique_categories)
# Out:
# Unique categories: [nan '💳 Financial services' '⛏️ Mining' 'Cement' '🧪 Chemicals'
#  '🏦 Insurance' '🔋 Electricity' '🏦 Banks' '⚓ Ports' 'Tires'
#  '💊 Pharmaceuticals' '🚂 Railways' '🌱 Fertilizer companies'
#  '✈️ Aircraft manufacturers' '📡 Telecommunication' '🛢 Oil&Gas' '🍴 Food'
#  '🏍 Motorcycle Manufacturers' '💼 Professional services'
#  '🎨 Paint & Coating' '⌚ Luxury goods' '🏭 Manufacturing' '🚚 Transportation'
#  '🛍️ Retail' '✈️ Airlines' '🚬 Tobacco' '🔩 Steel producers'
#  '🚘 Automotive Suppliers' '🏙 Conglomerate' '🚗 Automakers' '🏗 Construction']

# %%
# Summary statistics for numerical columns
print(df.describe())
# Out:
#        SerialNumber
# count    100.000000
# mean      50.500000
# std       29.011492
# min        1.000000
# 25%       25.750000
# 50%       50.500000
# 75%       75.250000
# max      100.000000

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# SerialNumber    0
# Names           0
# Rank            0
# Marketcap       0
# Share.Price     0
# Categories      8
# Revenue         0
# Country         0
# dtype: int64

# %%
# Filter companies from the finance category
finance_companies = df[df['Categories'] == 'Finance']
print(finance_companies.head())
# Out:
# Empty DataFrame
# Columns: [SerialNumber, Names, Rank, Marketcap, Share.Price, Categories, Revenue, Country]
# Index: []

# %%
# Sort the dataset by Rank in ascending order
sorted_df = df.sort_values(by='Rank', ascending=True)
print(sorted_df.head())
# Out:
#     SerialNumber               Names   Rank Marketcap Share.Price  \
# 23            24  Power Finance Corp  #1048  $16.64 B       $5.04
# 73            74  SBI Life Insurance  #1050  $16.63 B      $16.62
# 75            76   Grasim Industries  #1057  $16.46 B      $24.99
# 22            23      Hindustan Zinc  #1080  $15.93 B       $3.77
# 49            50       Tech Mahindra  #1102  $15.52 B      $15.91
#
#               Categories   Revenue Country
# 23  💳 Financial services   $3.59 B   India
# 73           🏦 Insurance  $14.15 B   India
# 75                   NaN  $14.87 B   India
# 22                   NaN   $3.52 B   India
# 49                   NaN   $6.39 B   India

# %%
# Calculate total revenue
total_revenue = df['Revenue'].sum()
print("Total revenue generated:", total_revenue)
# Out:
# Total revenue generated: $2.28 B$2.29 B$2.30 B$2.30 B$2.33 B$2.35 B$2.38 B$2.50 B$2.54 B$2.77 B$2.81 B$2.90 B$2.99 B$3.02 B$3.13 B$3.20 B$3.23 B$3.23 B$3.28 B$3.36 B$3.40 B$3.50 B$3.52 B$3.59 B$3.63 B$3.63 B$3.70 B$3.71 B$3.76 B$3.77 B$3.85 B$3.93 B$4.18 B$4.27 B$4.29 B$4.62 B$4.98 B$5.09 B$5.11 B$5.14 B$5.37 B$5.39 B$5.39 B$5.52 B$5.57 B$5.72 B$5.87 B$5.93 B$6.35 B$6.39 B$6.55 B$6.59 B$6.84 B$7.06 B$7.36 B$7.45 B$7.56 B$8.00 B$8.05 B$8.26 B$8.44 B$8.53 B$8.83 B$8.91 B$9.44 B$10.53 B$10.64 B$11.00 B$11.12 B$11.26 B$12.76 B$12.82 B$13.12 B$14.15 B$14.22 B$14.87 B$15.31 B$15.69 B$15.84 B$17.05 B$17.43 B$17.73 B$18.55 B$18.63 B$20.39 B$20.97 B$21.44 B$24.48 B$26.05 B$28.19 B$28.90 B$36.81 B$39.91 B$43.65 B$51.52 B$54.11 B$78.08 B$94.87 B$97.94 B$106.19 B

# %%
# Sort the dataset by Marketcap in descending order and select the top 10
top_10_marketcap = df.sort_values(by='Marketcap', ascending=False).head(10)

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.bar(top_10_marketcap['Names'], top_10_marketcap['Marketcap'], color='skyblue')
plt.title('Top 10 Companies with Highest Market Capitalization')
plt.xlabel('Company Names')
plt.ylabel('Market Capitalization')
plt.xticks(rotation=90)
plt.show()

# %%
# Plot the distribution of companies based on revenue
plt.figure(figsize=(20, 6))
plt.hist(df['Revenue'], bins=20, color='orange', edgecolor='black')
plt.title('Distribution of Companies Based on Revenue')
plt.xlabel('Revenue')
plt.xticks(rotation=90)
plt.ylabel('Number of Companies')
plt.show()

# %%
# Plot the share prices of different companies
plt.figure(figsize=(15, 20))
plt.bar(df['Names'], df['Share.Price'], color='green')
plt.title('Share Prices of Different Companies')
plt.xlabel('Company Names')
plt.ylabel('Share Price')
plt.xticks(rotation=90)
plt.show()

# %%
# Plot the distribution of companies based on ranks
plt.figure(figsize=(20, 6))
plt.hist(df['Rank'], bins=20, color='purple', edgecolor='black')
plt.title('Distribution of Companies Based on Rank')
plt.xlabel('Rank')
plt.xticks(rotation=90)
plt.ylabel('Number of Companies')
plt.show()

# %%
# Sort the dataset by Revenue in descending order and select the top 10
top_10_revenue = df.sort_values(by='Revenue', ascending=False).head(10)

# Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(top_10_revenue['Names'], top_10_revenue['Revenue'], color='red')
plt.title('Top 10 Companies with Highest Revenue')
plt.xlabel('Revenue')
plt.ylabel('Company Names')
plt.show()

# %%
# Count the number of companies from each country
country_counts = df['Country'].value_counts()

# Plot the bar chart
plt.figure(figsize=(10, 6))
country_counts.plot(kind='bar', color='green')
plt.title('Distribution of Companies by Country')
plt.xlabel('Countries')
plt.ylabel('Number of Companies')
plt.xticks(rotation=45)
plt.show()

# %%
# Extract numerical values from 'Revenue' column
df['Revenue'] = df['Revenue'].str.replace(r'\D', '', regex=True).astype(float)

# Define revenue ranges (you can adjust these as needed)
low_revenue_range = (0, 1000)
medium_revenue_range = (1001, 10000)
high_revenue_range = (10001, df['Revenue'].max())

# Categorize companies based on revenue ranges
df['RevenueRange'] = pd.cut(df['Revenue'], bins=[low_revenue_range[0], medium_revenue_range[0], high_revenue_range[0], high_revenue_range[1]], labels=['Low', 'Medium', 'High'])

# Count the number of companies in each revenue range
revenue_range_counts = df['RevenueRange'].value_counts()

# Create a pie chart
fig = px.pie(revenue_range_counts, values=revenue_range_counts.values, names=revenue_range_counts.index, title='Distribution of Companies by Revenue Range')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Select the top 5 categories by count
top_categories = df['Categories'].value_counts().nlargest(5)

# Create a pie chart
fig = px.pie(top_categories, values=top_categories.values, names=top_categories.index, title='Top 5 Categories of Companies')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Exclude non-numeric columns from the correlation calculation
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Plot heatmap for the numeric columns
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap for the Numeric Columns')
plt.show()

# %%
# Create a pairplot for the entire dataset
sns.pairplot(df)
plt.suptitle('Pairplot for the Entire Dataset', y=1.02)
plt.show()

# %%
# Create a histogram for Revenue
plt.hist(df['Revenue'])
# Out:
# (array([70., 17.,  4.,  3.,  2.,  0.,  0.,  1.,  1.,  2.]),
#  array([  228. ,  1267.1,  2306.2,  3345.3,  4384.4,  5423.5,  6462.6,
#          7501.7,  8540.8,  9579.9, 10619. ]),
#  <BarContainer object of 10 artists>)

# %%
# Create a boxplot for Revenue
sns.boxplot(df['Revenue'])
# Out:
# <Axes: ylabel='Revenue'>
